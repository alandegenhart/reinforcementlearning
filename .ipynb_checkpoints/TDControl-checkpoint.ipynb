# %% [markdown]
# ## TD control
# This notebook provides examples of different temporal difference-based approaches to control.

# %% [markdown]
# ### Setup
# Load the required modules as well as some other standard ones that might be needed.

# %%
# Setup environment and import standard modules
import sys
import os
import datetime
import numpy as np
import pandas as pd

# Import numerical libraries (skip these for now)
#import sklearn as skl
#from sklearn import linear_model, metrics
#import tensorflow as tf
#from tensorflow import keras
#print('Tensorflow version: {}'.format(tf.__version__))

# Set up plotting (inline)
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# Import custom modules
#sys.path.append(os.path.join(os.getcwd(), 'modules'))
#import plottools as pt

# Import OpenAI Gym
import gym
print('Open AI Gym version: {}'.format(gym.__version__))

# Autoreload (see https://ipython.readthedocs.io/en/stable/config/extensions/autoreload.html)
# %load_ext autoreload
# %autoreload 2
# Out:
# Open AI Gym version: 0.15.4

# %% [markdown]
# ### On-policy TD control (Sarsa)

# %% [markdown]
# A few observations:
# - This environment is a bit tricky to use.  Rewards are very scarce, which means that learning is difficulty unless there is a lot of exploration.
# - Having a high epsilon is probably good for a while in order to encourage exploration. Once a sufficient number of rewards have been encountered, it might make sense to start to taper this towards 0.
# - Turning off randomness in the environment makes it very difficult to find a reward with a small epsilon
# - The maximum reward rate when the randomness is turned off tends to plateau at a little less than $1-\epsilon$. When environmental randomness is on, the final reward rate is ~0.45 for $\epsilon = 0.05$.

# %%
import discrete

episodes = 100000
block_size = int(episodes/20)
eps = 0.5
is_slippery = False

# Test classes
env = gym.make('FrozenLake-v0', is_slippery=is_slippery)
TDBase_Agent = discrete.TDControl(env)
Sarsa_Agent = discrete.Sarsa(env)
Q_Agent = discrete.QLearning(env)
ESarsa_Agent = discrete.ExpectedSarsa(env)

TDBase_Agent.info()
Sarsa_Agent.info()
Q_Agent.info()
ESarsa_Agent.info()
# Out:
# Class: TDControl (base class)
# Class: Sarsa
# Class: Q-learning
# Class: Expected Sarsa

# %%
# Run Agent

episodes = 20000
block_size = int(episodes/20)
eps = 0.2
is_slippery = True

# Create environment and initialize agent
env = gym.make('FrozenLake-v0', is_slippery=is_slippery)
Agent = discrete.ExpectedSarsa(env, init_mode='random')
steps, rewards = Agent.run(episodes, block_size=block_size, eps=eps)
env.close()
# Out:
# Episode 1000 finished: reward rate = 0.146
# Episode 2000 finished: reward rate = 0.167
# Episode 3000 finished: reward rate = 0.201
# Episode 4000 finished: reward rate = 0.173
# Episode 5000 finished: reward rate = 0.195
# Episode 6000 finished: reward rate = 0.199
# Episode 7000 finished: reward rate = 0.195
# Episode 8000 finished: reward rate = 0.166
# Episode 9000 finished: reward rate = 0.164
# Episode 10000 finished: reward rate = 0.22
# Episode 11000 finished: reward rate = 0.173
# Episode 12000 finished: reward rate = 0.186
# Episode 13000 finished: reward rate = 0.214
# Episode 14000 finished: reward rate = 0.189
# Episode 15000 finished: reward rate = 0.176
# Episode 16000 finished: reward rate = 0.17
# Episode 17000 finished: reward rate = 0.182
# Episode 18000 finished: reward rate = 0.201
# Episode 19000 finished: reward rate = 0.187
# Episode 20000 finished: reward rate = 0.185

# %%
# Plot results

# Calculate reward rate as the running average over a the number of trials specified by update_block
reward_rate = np.convolve(rewards, np.ones(block_size), mode='valid') / block_size
episode_number = np.arange(block_size, episodes+1)

# Plot reward rate vs episodes
plt.plot(episode_number, reward_rate, color='k')
plt.ylabel('Reward rate')
plt.xlabel('Episodes')
plt.xlim(0, episodes)
plt.ylim(0, np.max(reward_rate))
plt.show()

Agent.Q
# Out:
# array([[0.06650026, 0.06362132, 0.06057308, 0.06218882],
#        [0.04526719, 0.02845403, 0.03185044, 0.05764621],
#        [0.0597673 , 0.05802554, 0.05982219, 0.05581934],
#        [0.0396706 , 0.04300935, 0.02552502, 0.05263727],
#        [0.09530389, 0.06576936, 0.0507068 , 0.05522331],
#        [0.        , 0.        , 0.        , 0.        ],
#        [0.05052256, 0.06386519, 0.04604105, 0.00995668],
#        [0.        , 0.        , 0.        , 0.        ],
#        [0.07871739, 0.10814991, 0.09354114, 0.14383929],
#        [0.16259002, 0.23058867, 0.20175088, 0.0743683 ],
#        [0.20554711, 0.13065268, 0.19699586, 0.09748118],
#        [0.        , 0.        , 0.        , 0.        ],
#        [0.        , 0.        , 0.        , 0.        ],
#        [0.17647085, 0.37270732, 0.27776446, 0.26525778],
#        [0.47046664, 0.760606  , 0.47185857, 0.50533759],
#        [0.        , 0.        , 0.        , 0.        ]])

# %%
x = 'abc'
y = ['zeros', 'random', 'optimistic']
x = 'zeros' if x not in y
# Out:
#   File "<ipython-input-25-5cfb46ed8519>", line 3
#     x = 'zeros' if x not in y
#                              ^
# SyntaxError: invalid syntax
